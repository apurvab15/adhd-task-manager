# %%
import google.generativeai as genai
import json

genai.configure(api_key="AIzaSyA99frxRyPRxQd2miH_sPVntYYW3qEBxMo")
task_model = genai.GenerativeModel("models/gemini-2.5-pro")

def break_down_task(task, subtype):
    """
    Breaks down a task into smaller subtasks based on ADHD subtype.
    """

    prompt = f"""
You are an ADHD-aware task structuring assistant.

Break down the user's task into actionable subtasks based on their ADHD subtype.

ADHD subtype behavior rules:

Inattentive → The Calm Organizer:
- Provide simplified steps
- Reduce cognitive load
- Maintain steady pacing
- Use clear, sequential order

Hyperactive–Impulsive → The Energetic Achiever:
- Use short micro-tasks
- Provide quick wins
- Include fast feedback loops
- Keep steps energetic and engaging

Combined → The Adaptive Balancer:
- Mix calm/structured phases with energetic micro-tasks
- Allow flexible switching
- Medium-length steps
- Balanced stimulation

User ADHD subtype: {subtype}
User task: "{task}"

Return ONLY clean JSON:

{{
  "subtype": "{subtype}",
  "original_task": "{task}",
  "subtasks": [],
  "explanation": ""
}}
"""

    response = task_model.generate_content(prompt)
    txt = response.text

    # Safe JSON extraction
    try:
        i = txt.index("{")
        j = txt.rindex("}") + 1
        return json.loads(txt[i:j])
    except:
        raise ValueError("Invalid JSON returned:\n" + txt)

# %%
result = break_down_task(
    task="Prepare a 15-slide presentation on supply chain analytics",
    subtype="Inattentive"
)

print(json.dumps(result, indent=4))
# Out:
# {
#     "subtype": "Inattentive",
#     "original_task": "Prepare a 15-slide presentation on supply chain analytics",
#     "subtasks": [
#         {
#             "step": 1,
#             "title": "Set Up Your Foundation",
#             "description": "Open a new presentation file and choose a simple, clean template. This is your easy starting point."
#         },
#         {
#             "step": 2,
#             "title": "Create a Clear Outline",
#             "description": "Make 15 blank slides and give each one a title to create a 'skeleton' for your presentation (e.g., Title, Intro, Why it Matters, How it Works, Example, Conclusion)."
#         },
#         {
#             "step": 3,
#             "title": "Focus on the Beginning",
#             "description": "Write the content for only the first 3 slides (Title and Introduction). Don't worry about the rest for now."
#         },
#         {
#             "step": 4,
#             "title": "Fill in the Middle Sections",
#             "description": "Work on one section at a time. Add the main bullet points for the 'Why it Matters' and 'How it Works' slides."
#         },
#         {
#             "step": 5,
#             "title": "Add a Concrete Example",
#             "description": "Find a simple case study or example and dedicate a few slides to explaining it. This makes the topic easier to understand."
#         },
#         {
#             "step": 6,
#             "title": "Write the Conclusion",
#             "description": "Draft your summary and 'Q&A' slides. This completes the first draft of all your text."
#         },
#         {
#             "step": 7,
#             "title": "Review the Words",
#             "description": "Read through all the text you've written from the beginning. Check for clarity and fix any typos."
#         },
#         {
#             "step": 8,
#             "title": "Add Visuals",
#             "description": "Go through the presentation one more time, this time adding one simple image or chart per key slide to support your message."
#         },
#         {
#             "step": 9,
#             "title": "Practice a Final Run-Through",
#             "description": "Read the entire presentation out loud from start to finish to ensure it flows well and feels complete."
#         }
#     ],
#     "explanation": "This plan is designed to be calm and clear, helping you build the presentation one step at a time without feeling overwhelmed. We start by creating a simple structure (the 'skeleton') so you always know what's next. Then, we fill in each section one by one, focusing on a small part of the task at a time. This sequential process reduces mental clutter and helps you build momentum steadily from start to finish."
# }

# %%
result = break_down_task(
    task="Prepare a 15-slide presentation on supply chain analytics",
    subtype="Hyperactive–Impulsive"
)

print(json.dumps(result, indent=4))
# Out:
# {
#     "subtype": "Hyperactive\u2013Impulsive",
#     "original_task": "Prepare a 15-slide presentation on supply chain analytics",
#     "subtasks": [
#         {
#             "step": 1,
#             "title": "5-Minute Idea Blast",
#             "description": "Set a 5-min timer. Rapidly list every word/idea related to 'supply chain analytics'. No filter! Circle the top 5-7 to be your main points. GO!"
#         },
#         {
#             "step": 2,
#             "title": "Data Dash: Sprint 1 (10 mins)",
#             "description": "Find ONE powerful statistic for one of your main points. Paste it into a document. Done!"
#         },
#         {
#             "step": 3,
#             "title": "Data Dash: Sprint 2 (10 mins)",
#             "description": "Hunt for ONE compelling image or chart for another main point. Save it. Boom!"
#         },
#         {
#             "step": 4,
#             "title": "Slide Sprint: The First 5",
#             "description": "Open your presentation app. Pick a bold template. Create a Title slide, then one slide for each of your first 4 main points/data points. One idea per slide. Fast!"
#         },
#         {
#             "step": 5,
#             "title": "MOVE! (2-Minute Reset)",
#             "description": "Get up, stretch, do a few jumping jacks, or walk around. Reset your brain and body."
#         },
#         {
#             "step": 6,
#             "title": "Slide Sprint: The Middle 5",
#             "description": "Tackle slides 6-10. Create one slide for each remaining main point or a new piece of data. Keep the pace high!"
#         },
#         {
#             "step": 7,
#             "title": "Quick Win Check-in",
#             "description": "You should have 10 slides now. High-five yourself! You're crushing it."
#         },
#         {
#             "step": 8,
#             "title": "Slide Sprint: The Final 5",
#             "description": "Knock out slides 11-15. Add a quick case study, a future trends slide, a summary, and a big 'Thank You / Q&A' slide. Almost there!"
#         },
#         {
#             "step": 9,
#             "title": "10-Minute Power Polish",
#             "description": "Set a 10-min timer. Blast through the slides. Is the font big? Are there too many words? Cut, cut, cut! Make it punchy. Add ONE cool animation if you want."
#         },
#         {
#             "step": 10,
#             "title": "Rehearsal Race (5 mins)",
#             "description": "Talk through your slides out loud, as fast as you can. The goal is to get a feel for the flow, not perfection. When the timer's up, you're done. CELEBRATE!"
#         }
#     ],
#     "explanation": "This plan is built for speed and momentum. It uses short, high-energy 'sprints' to create quick wins and maintain focus. By breaking the task into rapid-fire rounds with built-in movement breaks and clear finish lines, it keeps engagement high and prevents burnout, turning a big project into a series of achievable challenges."
# }

# %%
result = break_down_task(
    task="Prepare a 15-slide presentation on supply chain analytics",
    subtype="Combined"
)

print(json.dumps(result, indent=4))
# Out:
# {
#     "subtype": "Combined",
#     "original_task": "Prepare a 15-slide presentation on supply chain analytics",
#     "subtasks": [
#         {
#             "id": 1,
#             "title": "Brain Dump Sprint (15 mins)",
#             "description": "Set a timer for 15 minutes. Rapidly list every possible idea, keyword, or concept related to the topic. Don't organize yet, just get it all out. This is a quick, energetic start to get momentum."
#         },
#         {
#             "id": 2,
#             "title": "Theme Sorting (Focus Block)",
#             "description": "Switch to a calmer task. Review your brain dump and group related ideas into 3-5 main themes (e.g., 'Intro', 'Key Metrics', 'Case Study', 'Future Trends'). This structures your chaos."
#         },
#         {
#             "id": 3,
#             "title": "Skeleton Outline",
#             "description": "Open your presentation software. Create 15 blank slides and give each one a title based on your themes. This builds the backbone of your presentation without the pressure of filling it in yet."
#         },
#         {
#             "id": 4,
#             "title": "Content Dash (25 mins)",
#             "description": "Time for another sprint! Pick the 5 easiest slides from your outline and write the main bullet points for them. Aim for progress, not perfection."
#         },
#         {
#             "id": 5,
#             "title": "Visual Scavenger Hunt (15 mins)",
#             "description": "Switch gears to a creative task. Spend 15 minutes finding interesting charts, graphs, or images for 5-7 of your slides. Drop them in without worrying about perfect placement."
#         },
#         {
#             "id": 6,
#             "title": "Deep Dive Session (45 mins)",
#             "description": "Schedule a focused work block to tackle the most complex section of your presentation. Put on some focus music, close other tabs, and flesh out the data-heavy slides."
#         },
#         {
#             "id": 7,
#             "title": "Quick Design Win",
#             "description": "Apply a pre-made design template to your entire presentation. This gives you an instant feeling of accomplishment and makes everything look more cohesive."
#         },
#         {
#             "id": 8,
#             "title": "Final Polish & Rehearsal",
#             "description": "Go through the presentation slide-by-slide. Read the text aloud to catch errors and check the flow. Tidy up your visuals and add speaker notes if needed."
#         }
#     ],
#     "explanation": "This plan is designed for the Adaptive Balancer, balancing focused, structured work with energetic, high-feedback tasks. It starts with a high-energy 'Brain Dump' to build momentum, then shifts to a calmer 'Theme Sorting' phase for structure. The plan allows you to flexibly switch between writing content, hunting for visuals, and designing, which helps maintain stimulation and prevent burnout or boredom. The mix of timed sprints and focused blocks provides the balanced approach needed to complete a complex project."
# }
